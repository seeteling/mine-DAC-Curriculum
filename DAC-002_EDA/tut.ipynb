# %%
import pandas as pd         # data manipulation & analysis
import numpy as np          # numerical & mathematical operations
import matplotlib.pyplot as plt         # for creating visualisations
import seaborn as  sns 

df = pd.read_csv(r'C:\Users\E-Ling\Downloads\Netflix_Userbase.csv')

# %%
df.isnull().sum(
)
# Out:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# Plan Duration        0
# dtype: int64

# %%
duplicate= df[df.duplicated()]
print(duplicate.shape)
# Out:
# (0, 10)

# %%
df.info
# Out:
# <bound method DataFrame.info of       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
#what subscription types are there
print(df["Subscription Type"].unique())
# Out:
# ['Basic' 'Premium' 'Standard']

# %%
print(df["Plan Duration"].unique())
# Out:
# ['1 Month']

# %%
print(df["Monthly Revenue"].unique())
# Out:
# [10 15 12 13 11 14]

# %%
df['Monthly Revenue'].value_counts().sort_index().plot(kind="bar",title="mothly sales")
plt.rcParams['figure.figsize']=(14,6)
plt.show()

# %%
df['Join Date'].value_counts().sort_index().plot(kind="bar",title="mothly sales")
plt.rcParams['figure.figsize']=(20,14)
plt.show()

# %%
df['Subscription Type'].value_counts().plot(kind="bar",title="types of subs")
plt.rcParams['figure.figsize']=(14,6)
plt.show()

# %%
df['Country'].value_counts().plot(kind="bar",title="users per country")
plt.rcParams['figure.figsize']=(14,6)
plt.show()

# %%
sns.barplot(df['Subscription Type'],hue =df["Gender"])
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sns.barplot(df['Subscription Type'],hue =df["Gender"])
#       2 plt.show
#
# File c:\Users\E-Ling\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
#    2346     color=color,
#    2347     legend=legend,
#    2348 )
#    2350 if ax is None:
# ...
